# %% [markdown]
# Day 6 – Seaborn & Preprocessing

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print("Seaborn Version:", sns.__version__)
# Out:
# Seaborn Version: 0.13.2

# %%
# Load built-in dataset
df = sns.load_dataset('tips')
print(df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Custom sinplot
def sinplot(flip=1):
    x = np.linspace(0,14,100)
    for i in range(1,5):
        plt.plot(x,np.sin(x+i*0.5)*(7-i)*flip)

sns.set()
sinplot()
plt.title("Basic Sinplot using Seaborn")
plt.show()

# %%
# Themes
for style in ["darkgrid", "whitegrid", "white", "ticks"]:
    sns.set_style(style)
    sinplot()
    plt.title(f"Seaborn style: {style}")
    sns.despine()
    plt.show()

# %%
# Color Palettes
sns.palplot(sns.color_palette())  # Default
plt.show()

sns.palplot(sns.color_palette("Greens"))  # Sequential
plt.show()

sns.palplot(sns.color_palette("BrBG", 7))  # Diverging
plt.show()

# %%
# Histogram (Seaborn)
sns.histplot(df['tip'], kde=False)
plt.title("Tip Distribution")
plt.show()

# %%
#  Scatter Plot (Iris)
iris = sns.load_dataset('iris')
sns.jointplot(x='petal_length', y='petal_width', data=iris)
plt.show()

# %%
# KDE Plot
sns.jointplot(x='petal_length', y='petal_width', data=iris, kind='kde')
plt.show()

# %%
# Pair Plot
sns.pairplot(iris, hue='species', diag_kind="kde", palette="husl")
plt.show()

# %%
# Strip & Swarm
sns.stripplot(x="species", y="petal_length", data=iris)
plt.title("Stripplot")
plt.show()

# %%
sns.stripplot(x="species", y="petal_length", data=iris, jitter=True)
plt.title("Stripplot with Jitter")
plt.show()

# %%
sns.swarmplot(x="species", y="petal_length", data=iris)
plt.title("Swarmplot")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Box and Violin
sns.boxplot(x="species", y="petal_length", data=iris)
plt.title("Boxplot")
plt.show()

# %%
tips = sns.load_dataset('tips')
sns.violinplot(x="day", y="total_bill", data=tips)
plt.title("Violin Plot - Tips")
plt.show()
